# %%
# Base imports
import os
import pickle

# Compute imports
import numpy as np
import pandas as pd
import scipy
from tqdm.notebook import tqdm, trange

# Plotting imports
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
from matplotlib import pyplot as plt
import seaborn as sns
from plotly import express as px

import pandas as pd
# ML import
#from sklearn.decomposition import NMF
#from sklearn.metrics import mean_squared_error, median_absolute_error

from pyphylon.pangenome import find_pangenome_segments, find_pangenome_segments_panaroo
from pyphylon.util import load_config

# %%
CONFIG = load_config("config.yml")
WORKDIR = CONFIG["WORKDIR"]
SPECIES = CONFIG["PG_NAME"]

# %%
df_genes = pd.read_pickle(os.path.join(WORKDIR, f'processed/cd-hit-results/{SPECIES}_strain_by_gene.pickle.gz'))
df_genes.fillna(0, inplace=True)
df_genes = df_genes.sparse.to_dense().astype('int8')

display(
    df_genes.shape,
    df_genes.head()
)

# %%
metadata = pd.read_csv(os.path.join(WORKDIR, 'interim/mash_scrubbed_species_metadata_2b.csv'), index_col=0, dtype='object')

display(
    metadata.shape,
    metadata.head()
)

# %%
# Filter metadata for Complete sequences only
metadata_complete = metadata[metadata.genome_status == 'Complete'] # filter for only Complete sequences

# Filter P matrix for Complete sequences only
df_genes_complete = df_genes[metadata_complete.genome_id]
inCompleteseqs = df_genes_complete.sum(axis=1) > 0 # filter for genes found in complete sequences
df_genes_complete = df_genes_complete[inCompleteseqs]

df_genes_complete.shape

# %%
df_gene_freq = df_genes.sum(axis=1)
df_gene_freq.hist()
fig, ax = plt.subplots()
sns.histplot(df_gene_freq, binwidth=df_genes.shape[1] // 10, ax=ax)
plt.yscale('log')
plt.show()

# %%
fig, ax = plt.subplots()

segments, popt, r_squared, mae, ax = find_pangenome_segments(df_genes, threshold=0.1, ax=ax)

# %%
df_freq = df_genes.sum(axis=1)

df_core = df_genes[df_freq > np.floor(segments[0])]
df_rare = df_genes[df_freq < np.ceil(segments[1])]

acc_gene_list = list(set(df_genes.index)
                     - set(df_core.index)
                     - set(df_rare.index)
                    )

df_acc = df_genes.loc[acc_gene_list].copy()

display(
    df_core.shape,
    df_acc.shape,
    df_rare.shape
)

# %%
number_of_decimal_places = 4

core_genome_threshold = segments[0] / df_genes.shape[1]
rare_genome_threshold = segments[1] / df_genes.shape[1]
print("Core Genome Cutoff: ", str(core_genome_threshold)[:number_of_decimal_places + 2])
print("Rare Genome Cutoff: ", str(rare_genome_threshold)[:number_of_decimal_places + 2])

# %% [markdown]
# # Run Panaroo
# If you want to use a panaroo-based pangenome, set the PANAROO field in the config file to "True". You will also need to set the CORE_GENOME_CUTOFF field to the value displayed above. There are several other optional panaroo fields which can be set to adjust tool settings based on user preference (i.e. an option to run core genome alignment in Panaroo if this is desired for downstream use).
#
#
# Following this, you will need to run the _panaroo_ workflow in the workflows folder in order to compute the panaroo results. If this is done, the results will then be processed below in order to compute the appropriate CAR genomes (either CD-HIT or Panaroo based) for downstream in Phylon Analysis.

# %%
CONFIG = load_config("config.yml")
PANAROO_RUN = CONFIG["PANAROO"]

# %%
if PANAROO_RUN:
    df_genes_panaroo = pd.read_csv(os.path.join(WORKDIR, f'processed/panaroo_results/{SPECIES}/gene_presence_absence.Rtab'), sep  = '\t', index_col = 'Gene')

    # plot genes histograms
    df_gene_freq_panaroo = df_genes_panaroo.sum(axis=1)
    df_gene_freq_panaroo.hist()
    plt.title("Gene Frequency Histogram")
    plt.ylabel("Total Count of Genes")
    plt.xlabel("Number of Strains")
    plt.show()
    fig, ax = plt.subplots()
    sns.histplot(df_gene_freq_panaroo, binwidth=df_genes.shape[1] // 10, ax=ax)
    plt.yscale('log')
    
    plt.title("Gene Frequency Histogram (log-scaled)")
    plt.ylabel("Total Count of Genes (log)")
    plt.xlabel("Number of Strains")
    plt.show()


    fig, ax = plt.subplots()

    segments_panaroo, popt_panaroo, r_squared_panaroo, mae_panaroo, ax_panaroo = find_pangenome_segments_panaroo(df_genes_panaroo, threshold=0.1, ax=ax, 
                                                                                                        custom_core_threshold = core_genome_threshold,
                                                                                                        custom_rare_threshold = rare_genome_threshold)
    plt.title("Cumulative Gene Frequency Plot")
    plt.show()


    df_freq_panaroo = df_genes_panaroo.sum(axis=1)
    df_core_panaroo = df_genes_panaroo[df_freq_panaroo > np.floor(segments_panaroo[0])]
    df_rare_panaroo = df_genes_panaroo[df_freq_panaroo < np.ceil(segments_panaroo[1])]
    
    acc_gene_list_panaroo = list(set(df_genes_panaroo.index)
                         - set(df_core_panaroo.index)
                         - set(df_rare_panaroo.index)
                        )
    
    df_acc_panaroo = df_genes_panaroo.loc[acc_gene_list_panaroo].copy()
    
    display(
        'df_core_panaroo shape:',
        df_core_panaroo.shape,
        'df_acc_panaroo shape:',
        df_acc_panaroo.shape,
        'df_rare_panaroo shape:',
        df_rare_panaroo.shape
    )

# %% [markdown]
# # Save Results

# %%
if PANAROO_RUN:
    newpath = os.path.join(WORKDIR, 'processed/CAR_genomes/') 
    if not os.path.exists(newpath):
        os.makedirs(newpath)

    df_genes_panaroo = df_genes_panaroo.fillna(0).astype('int8')
    df_genes_panaroo = df_genes_panaroo.astype(pd.SparseDtype("int8", fill_value=0))
    df_genes_panaroo.to_pickle(
        os.path.join(WORKDIR, 'processed/CAR_genomes/df_genes.pickle.gz'),
        compression='gzip'
    )
    df_core_panaroo.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_core.csv'))
    df_acc_panaroo.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_acc.csv'))
    df_rare_panaroo.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_rare.csv'))

    df_genes = df_genes.fillna(0).astype('int8')
    df_genes = df_genes.astype(pd.SparseDtype("int8", fill_value=0))
    df_genes.to_pickle(
        os.path.join(WORKDIR, 'processed/CAR_genomes/df_genes_cdhit.pickle.gz'),
        compression='gzip'
    )
    df_core.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_core_cdhit.csv'))
    df_acc.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_acc_cdhit.csv'))
    df_rare.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_rare_cdhit.csv'))
else:
    newpath = os.path.join(WORKDIR, 'processed/CAR_genomes/') 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    df_genes = df_genes.fillna(0).astype('int8')
    df_genes = df_genes.astype(pd.SparseDtype("int8", fill_value=0))
    df_genes.to_pickle(
        os.path.join(WORKDIR, 'processed/CAR_genomes/df_genes_cdhit.pickle.gz'),
        compression='gzip'
    )
    df_core.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_core.csv'))
    df_acc.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_acc.csv'))
    df_rare.to_csv(os.path.join(WORKDIR, 'processed/CAR_genomes/df_rare.csv'))
